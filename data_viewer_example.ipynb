# %%
import numpy as np

# %%
data = np.load('/home/work/.jinupahk/virtualkss/rlds_dataset_builder/agialpha2lerobot_dataset/data/train/episode_0.npy', allow_pickle = True)

# %%
data
# Out:
# array([{'image': array([[[ 61,  19, 128],
#                [ 13,  47, 254],
#                [ 66, 244, 167],
#                ...,
#                [ 29,   2,  60],
#                [172, 245,  21],
#                [ 41, 117, 244]],
#
#               [[117, 134, 246],
#                [166, 154, 184],
#                [149, 225, 129],
#                ...,
#                [207, 101,  71],
#                [ 87, 248,  87],
#                [136, 127, 218]],
#
#               [[ 49, 171,  98],
#                [131,  23, 204],
#                [ 37, 164,   2],
#                ...,
#                [ 77,  95, 223],
#                [138, 224,  97],
#                [161, 221,  43]],
#
#               ...,
#
#               [[201, 147, 190],
#                [158, 183, 110],
#                [141, 185, 183],
#                ...,
#                [116,  78,  64],
#                [243, 218, 240],
#                [ 50,  76, 203]],
#
#               [[130, 112, 146],
# ...
